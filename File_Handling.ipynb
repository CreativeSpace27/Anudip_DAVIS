# %% [markdown]
# <a href="https://colab.research.google.com/github/CreativeSpace27/Anudip_DAVIS/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("data.txt", "a")
file.write("Wlcome to Python")
file.close()

# %%
file = open("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# Wlcome to Python

# %%
file = open("data.txt","a")
file.write("\n Student Name: Piyush Bhadade \n Division: A")
file.close()
# Out:
# Wlcome to Python

# %%
file = open("data.txt","r")
content = file.read()
print(content)
# Out:
# Wlcome to Python
#  Student Name: Piyush Bhadade
#  Division: A

# %%
file = open("data.txt","r")
content = file.read()
sum = 1
for i in content:
  if i == "\n":
    sum = sum +1
print("Numbers of line in the file is: ", sum)
# Out:
# Numbers of line in the file is:  3

# %%
try:
  file = open("datas.txt","r")
  content = file.read()
  print(content)
except FileNotFoundError:
  print("File not present")
# Out:
# File not present

# %%
#write is used to write content in the file it also used t overwrite the fie content
file = open("data.txt", "w")
file.write("My name is Piyush")
file.close()

#append is used to write the new content in the file
file = open("data.txt", "a")
file.write("Wlcome to Python")
file.close()

# %%
file = open("data.txt","r")
readfile = file.readlines()
print("Numbers of line in the file is: ", len(readfile))
# Out:
# Numbers of line in the file is:  3
